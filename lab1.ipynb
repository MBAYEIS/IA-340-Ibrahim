# %% [markdown]
# # lab 1

# %% [markdown]
# this is my first lab

# %%
import pandas as pd 

covid_data = pd.read_csv("s3://ia-340-fa25-ibrahim/data.csv")
covid_data.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...

# %%
crime_data = pd.read_csv("s3://ia-340-fa25-ibrahim/SPD_Crime_Data__2008-Present.csv")
crime_data.head()
# Out:
#   Report Number         Report DateTime   Offense ID            Offense Date  \
# 0   2013-217957  06/22/2013 09:29:00 PM   7686115988  06/22/2013 09:29:00 PM
# 1   2009-237520  07/08/2009 05:54:00 PM   7641304087  07/08/2009 07:00:00 AM
# 2   2015-079168  03/10/2015 02:06:00 PM   7680665743  03/10/2015 01:11:00 PM
# 3   2022-163752  06/26/2022 08:43:59 PM  34519102321  06/26/2022 06:16:00 PM
# 4   2017-268444  07/23/2017 12:41:00 AM   7637289721  07/22/2017 11:55:00 PM
#
#   NIBRS Group AB NIBRS Crime Against Category Offense Sub Category  \
# 0              A                       PERSON   AGGRAVATED ASSAULT
# 1              A                     PROPERTY        LARCENY-THEFT
# 2              A                     PROPERTY        LARCENY-THEFT
# 3              B                      SOCIETY             TRESPASS
# 4              A                       PERSON     ASSAULT OFFENSES
#
#   Shooting Type Group              Block Address     Latitude  \
# ...
